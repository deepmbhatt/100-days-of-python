# %%
#Importing the libraries
import pandas as pd
import numpy as np

# %%
#Importing the dataset
df = pd.read_csv("salaries_by_college_major.csv")

# %%
df.head(5)
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
#Describing the dataset
df.describe()
# Out:
#        Starting Median Salary  Mid-Career Median Salary  \
# count               50.000000                  50.00000
# mean             44310.000000               74786.00000
# std               9360.866217               16088.40386
# min              34000.000000               52000.00000
# 25%              37050.000000               60825.00000
# 50%              40850.000000               72000.00000
# 75%              49875.000000               88750.00000
# max              74300.000000              107000.00000
#
#        Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# count                          50.000000                          50.000000
# mean                        43408.000000                      142766.000000
# std                         12000.779567                       27851.249267
# min                         26700.000000                       96400.000000
# 25%                         34825.000000                      124250.000000
# ...

# %%
#Getting basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Undergraduate Major                51 non-null     object
#  1   Starting Median Salary             50 non-null     float64
#  2   Mid-Career Median Salary           50 non-null     float64
#  3   Mid-Career 10th Percentile Salary  50 non-null     float64
#  4   Mid-Career 90th Percentile Salary  50 non-null     float64
#  5   Group                              50 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 2.5+ KB

# %%
#Getting the shape of the dataset
df.shape
# Out:
# (51, 6)

# %%
df.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
#Removing the rows with missing values
clean_df = df.dropna()

# %%
clean_df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
#Accessing the columns of the dataset
clean_df["Undergraduate Major"]
# Out:
# 0                               Accounting
# 1                    Aerospace Engineering
# 2                              Agriculture
# 3                             Anthropology
# 4                             Architecture
# 5                              Art History
# 6                                  Biology
# 7                      Business Management
# 8                     Chemical Engineering
# 9                                Chemistry
# 10                       Civil Engineering
# 11                          Communications
# 12                    Computer Engineering
# 13                        Computer Science
# 14                            Construction
# 15                        Criminal Justice
# 16                                   Drama
# 17                               Economics
# 18                               Education
# 19                  Electrical Engineering
# 20                                 English
# 21                                    Film
# ...

# %%
#Accessing the value counts of the column
clean_df["Undergraduate Major"].value_counts()
# Out:
# Undergraduate Major
# Accounting                              1
# Math                                    1
# Health Care Administration              1
# History                                 1
# Hospitality & Tourism                   1
# Industrial Engineering                  1
# Information Technology (IT)             1
# Interior Design                         1
# International Relations                 1
# Journalism                              1
# Management Information Systems (MIS)    1
# Marketing                               1
# Mechanical Engineering                  1
# Aerospace Engineering                   1
# Music                                   1
# Nursing                                 1
# Nutrition                               1
# Philosophy                              1
# Physician Assistant                     1
# Physics                                 1
# Political Science                       1
# Psychology                              1
# ...

# %%
#Accessing the unique values of the column
clean_df["Undergraduate Major"].unique()
# Out:
# array(['Accounting', 'Aerospace Engineering', 'Agriculture',
#        'Anthropology', 'Architecture', 'Art History', 'Biology',
#        'Business Management', 'Chemical Engineering', 'Chemistry',
#        'Civil Engineering', 'Communications', 'Computer Engineering',
#        'Computer Science', 'Construction', 'Criminal Justice', 'Drama',
#        'Economics', 'Education', 'Electrical Engineering', 'English',
#        'Film', 'Finance', 'Forestry', 'Geography', 'Geology',
#        'Graphic Design', 'Health Care Administration', 'History',
#        'Hospitality & Tourism', 'Industrial Engineering',
#        'Information Technology (IT)', 'Interior Design',
#        'International Relations', 'Journalism',
#        'Management Information Systems (MIS)', 'Marketing', 'Math',
#        'Mechanical Engineering', 'Music', 'Nursing', 'Nutrition',
#        'Philosophy', 'Physician Assistant', 'Physics',
#        'Political Science', 'Psychology', 'Religion', 'Sociology',
# ...

# %%
#Accessing the number of unique values of the column
clean_df["Undergraduate Major"].nunique()
# Out:
# 50

# %%
#Accessing the maximum value of the column
clean_df["Starting Median Salary"].max()
# Out:
# 74300.0

# %%
#Accessing the index of the maximum value of the column
clean_df["Starting Median Salary"].idxmax()
# Out:
# 43

# %%
#Accessing the Median salary with the maximum value of the column
clean_df["Starting Median Salary"].iloc[43]
# Out:
# 74300.0

# %%
#finding the major with the highest starting median salary
clean_df["Undergraduate Major"].iloc[43]
# Out:
# 'Physician Assistant'

# %%
#Accessing the row with the maximum value of the column
clean_df.iloc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %%
#Accessing the row with the maximum value of the mid career median salary and the major
print(clean_df['Mid-Career Median Salary'].max())
print(f"Index for the max mid career salary: {clean_df['Mid-Career Median Salary'].idxmax()}")
clean_df['Undergraduate Major'][8]
# Out:
# 107000.0
# Index for the max mid career salary: 8
# 'Chemical Engineering'

# %%
#Accessing the row with the minimum value of the column and the major
print(clean_df['Starting Median Salary'].min())
clean_df['Undergraduate Major'].loc[clean_df['Starting Median Salary'].idxmin()]
# Out:
# 34000.0
# 'Spanish'

# %%
#Accessing the row with the minimum value of the column and the major
clean_df.loc[clean_df['Mid-Career Median Salary'].idxmin()]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary                 34900.0
# Mid-Career Median Salary               52000.0
# Mid-Career 10th Percentile Salary      29300.0
# Mid-Career 90th Percentile Salary     102000.0
# Group                                     HASS
# Name: 18, dtype: object

# %%
#Finding spread of the salaries
clean_df["spread"] = clean_df["Mid-Career 90th Percentile Salary"] - clean_df["Mid-Career 10th Percentile Salary"]
# Out:
# C:\Users\Deep\AppData\Local\Temp\ipykernel_19432\3143725266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df["spread"] = clean_df["Mid-Career 90th Percentile Salary"] - clean_df["Mid-Career 10th Percentile Salary"]

# %%
#Sorting the dataset by the spread of the salaries in ascending order to find the majors with the lowest spread
low_risk = clean_df.sort_values("spread")

# %%
low_risk[["Undergraduate Major", "spread"]].head()
# Out:
#            Undergraduate Major   spread
# 40                     Nursing  50700.0
# 43         Physician Assistant  57600.0
# 41                   Nutrition  65300.0
# 49                     Spanish  65400.0
# 27  Health Care Administration  66400.0

# %%
#Sorting the dataset by the mid career 90th percentile salary in descending order to find the majors with the highest potential
highest_potential = clean_df.sort_values('Mid-Career 90th Percentile Salary', ascending=False)
highest_potential[['Undergraduate Major', 'Mid-Career 90th Percentile Salary']].head()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 17             Economics                           210000.0
# 22               Finance                           195000.0
# 8   Chemical Engineering                           194000.0
# 37                  Math                           183000.0
# 44               Physics                           178000.0

# %%
#Sorting the dataset by the spread of the salaries in descending order to find the majors with the highest spread
highest_spread = clean_df.sort_values('spread', ascending=False)
highest_spread[['Undergraduate Major', 'spread']].head()
# Out:
#    Undergraduate Major    spread
# 17           Economics  159400.0
# 22             Finance  147800.0
# 37                Math  137800.0
# 36           Marketing  132900.0
# 42          Philosophy  132500.0

# %%
#Grouping the dataset by the major and finding the mean of the salaries
clean_df.groupby('Group').count()
# Out:
#           Undergraduate Major  Starting Median Salary  \
# Group
# Business                   12                      12
# HASS                       22                      22
# STEM                       16                      16
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                        12                                 12
# HASS                            22                                 22
# STEM                            16                                 16
#
#           Mid-Career 90th Percentile Salary  spread
# Group
# Business                                 12      12
# HASS                                     22      22
# STEM                                     16      16
